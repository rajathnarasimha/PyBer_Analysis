# %%
# %matplotlib inline

import matplotlib.pyplot as plt
#matplotlib.__version__

# %%
# Set the x-axis to a list of strings for each month.
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

# %%
# Create the plot
plt.plot(x_axis, y_axis)

# %%
# Create the plot with ax.plt()
fig, ax = plt.subplots()
ax.plot(x_axis, y_axis)

# %%
# Create the plot with ax.plt()
fig = plt.figure()
ax = fig.add_subplot()

# %%
# Create the plot with ax.plt()
ax = plt.axes()
ax.plot(x_axis, y_axis)

# %%
# Create the plot.
plt.plot(x_axis, y_axis)
plt.show()

# %%
# Create the plot and add a label for the legend.
plt.plot(x_axis, y_axis, marker="*", color="blue", linewidth=2, label='Boston')
# Create labels for the x and y axes.
plt.xlabel("Date")
plt.ylabel("Fare($)")
# Set the y limit between 0 and 45.
plt.ylim(0,45)
# Create a title.
plt.title("PyBer Fare by Month")
# Add a grid.
plt.grid()
# Add the legend.
plt.legend()

# %%
# Create the plot with ax.plt()
fig, ax = plt.subplots()
ax.plot(x_axis, y_axis, marker='d', color="green", linewidth=2, label='Boston')
ax.legend()
ax.set_title("PyBer Fare by Month")
ax.set_xlabel("Date")
ax.set_ylabel("Fare($)")
ax.set_ylim(0,45)
ax.grid()

# %%
# Set the x-axis to a list of strings for each month.
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

# %%
plt.bar(x_axis,y_axis)
# Out:
# <BarContainer object of 12 artists>

# %%
# Create the plot.
plt.bar(x_axis, y_axis, color="green", label='Boston')
# Create labels for the x and y axes.
plt.xlabel('Date')
plt.ylabel('Fare($)')
# Create a title.
plt.title("PyBer Fare by Month")
# Add the legend.
plt.legend()

# %%
plt.barh(x_axis, y_axis)
# Out:
# <BarContainer object of 12 artists>

# %%
# Create the plot
plt.barh(y_axis, x_axis)
# Out:
# <BarContainer object of 12 artists>

# %%
# Create the plot.
plt.barh(x_axis, y_axis, color='magenta', label='Boston')
plt.gca().invert_yaxis()
plt.legend()
plt.xlabel("Fare($)")
plt.ylabel("Date")
plt.title("PyBer Fare By Month")
# Out:
# Text(0.5, 1.0, 'PyBer Fare By Month')

# %%
# Set the x-axis to a list of strings for each month.
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

# %%
# Create the plot with ax.plt()
fig, ax = plt.subplots()
ax.bar(x_axis, y_axis, color='k', label='New York')
# Out:
# <BarContainer object of 12 artists>

# %%
# Create the plot with ax.plt()
fig, ax = plt.subplots()
ax.barh(x_axis, y_axis)
# Out:
# <BarContainer object of 12 artists>

# %%
# Create the plot with ax.plt()
fig, ax = plt.subplots()
ax.barh(y_axis, x_axis)
# Out:
# <BarContainer object of 12 artists>

# %%
# Create the plot with ax.plt()
fig, ax = plt.subplots()
ax.barh(x_axis, y_axis, color='cyan', label='Chicago')
ax.legend()
ax.set_title("PyBer Fare By Month")
ax.set_xlabel("Fare($)")
ax.set_ylabel("Date")
ax.invert_yaxis()

# %%
# Set the x-axis to a list of strings for each month.
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

# %%
#plt.plot(x_axis, y_axis, 'o')

# %%
#plt.scatter(x_axis, y_axis)
plt.scatter(y_axis, x_axis, color='red', label='Chicago')
plt.title("PyBer Fare by Month")
plt.xlabel("Fare($)")
plt.ylabel("Date")
plt.legend()
plt.xlim(0,45)
plt.gca().invert_yaxis()

# %%
#Bubble chart
plt.scatter(x_axis, y_axis, s=y_axis)

# %%
y_axis_larger = []
for data in y_axis:
    y_axis_larger.append(data*3)

plt.scatter(x_axis, y_axis, s=y_axis_larger)

# %%
plt.scatter(x_axis, y_axis, s = [i * 3 for i in y_axis])

# %%
fig, ax =plt.subplots()
ax.scatter(x_axis,y_axis)

# %%
#Bubble Chart
fig, ax = plt.subplots()
ax.scatter(x_axis, y_axis, s=y_axis)

# %%
#Bubble Chart
fig, ax = plt.subplots()
alpha=20
ax.scatter(y_axis, x_axis, s=[i * 5 for i in y_axis], c='xkcd:sky blue', alpha=0.2,
           linewidth=2, edgecolors='black', label="Boston")
ax.legend()
ax.set_title("PyBer Fare by Month")
ax.set_xlabel("Date")
ax.set_ylabel("Fare($)")
ax.invert_yaxis()
ax.set_xlim(0,45)
# Out:
# (0, 45)

# %%
plt.pie(y_axis, labels=x_axis)

# %%
explode_values=[0,0,0,0,0,0,.2,0,0,0,0,0]
plt.subplots(figsize=(8, 8))
plt.pie(y_axis, labels=x_axis, autopct="%.1f%%", explode=explode_values)
# Out:
# ([<matplotlib.patches.Wedge at 0x11acb3bd0>,
#   <matplotlib.patches.Wedge at 0x11ad6e3d0>,
#   <matplotlib.patches.Wedge at 0x11ad6e750>,
#   <matplotlib.patches.Wedge at 0x11ae17790>,
#   <matplotlib.patches.Wedge at 0x11ad51350>,
#   <matplotlib.patches.Wedge at 0x11ac3ca90>,
#   <matplotlib.patches.Wedge at 0x11ad4ab10>,
#   <matplotlib.patches.Wedge at 0x11ad4a110>,
#   <matplotlib.patches.Wedge at 0x11ad51390>,
#   <matplotlib.patches.Wedge at 0x11ad51410>,
#   <matplotlib.patches.Wedge at 0x11ac74d10>,
#   <matplotlib.patches.Wedge at 0x11a993a50>],
#  [Text(1.0940372721655667, 0.11437852557419124, 'Jan'),
#   Text(0.9905193092273052, 0.4784051609753622, 'Feb'),
#   Text(0.4998632656180861, 0.9798656620606842, 'Mar'),
#   Text(-0.32930826971286276, 1.0495504101750999, 'April'),
#   Text(-0.9306200792045569, 0.5864693241605263, 'May'),
#   Text(-1.0983369533258995, -0.06046434452452757, 'June'),
#   Text(-0.913463027456946, -0.9249785389235748, 'July'),
#   Text(-0.23338752507546193, -1.0749559354406817, 'Aug'),
#   Text(0.021097559209412746, -1.099797660024518, 'Sept'),
#   Text(0.460981299980763, -0.9987473359504124, 'Oct'),
#   Text(0.8868706338501641, -0.6507384104340302, 'Nov'),
#   Text(1.0760953148482877, -0.22807646384834376, 'Dec')],
#  [Text(0.5967476029993999, 0.06238828667683158, '3.3%'),
#   Text(0.5402832595785301, 0.2609482696229248, '7.7%'),
#   Text(0.27265269033713785, 0.5344721793058277, '13.0%'),
#   Text(-0.17962269257065241, 0.5724820419136908, '11.7%'),
#   Text(-0.5076109522933946, 0.3198923586330143, '10.7%'),
#   Text(-0.5990928836323088, -0.03298055155883321, '8.9%'),
#   Text(-0.562131093819659, -0.5692175624145076, '14.5%'),
#   Text(-0.1273022864047974, -0.5863396011494626, '3.5%'),
#   Text(0.011507759568770587, -0.5998896327406462, '3.9%'),
#   Text(0.2514443454440525, -0.5447712741547703, '9.2%'),
#   Text(0.4837476184637258, -0.35494822387310737, '6.9%'),
#   Text(0.5869610808263387, -0.12440534391727841, '6.6%')])

# %%
# Assign 12 colors, one for each month.
colors = ["slateblue", "magenta", "lightblue", "green", "yellowgreen", "greenyellow", "yellow", "orange", "gold", "indianred", "tomato", "mistyrose"]
explode_values = (0, 0, 0, 0, 0, 0, 0.2, 0, 0, 0, 0, 0)
plt.subplots(figsize=(8, 8))
plt.pie(y_axis,
    explode=explode_values,
    colors=colors,
    labels=x_axis,
    autopct='%.1f%%')

#plt.show()

# %%
fig, ax = plt.subplots(figsize=(8,8))
colors = ["slateblue", "magenta", "lightblue", "green", "yellowgreen", "greenyellow", "yellow", "orange", "gold", "indianred", "tomato", "mistyrose"]

explode_values=[0,0,.2,0,0,0,.2,0,0,0,0,0]
ax.pie(y_axis, labels=x_axis, autopct="%.1f%%", explode=explode_values, shadow=True,
      startangle=95.0, colors=colors, counterclock=False)
# Out:
# ([<matplotlib.patches.Wedge at 0x11b233890>,
#   <matplotlib.patches.Wedge at 0x11b23d210>,
#   <matplotlib.patches.Wedge at 0x11b23d1d0>,
#   <matplotlib.patches.Wedge at 0x11b2477d0>,
#   <matplotlib.patches.Wedge at 0x11af48250>,
#   <matplotlib.patches.Wedge at 0x11af48d10>,
#   <matplotlib.patches.Wedge at 0x11af54750>,
#   <matplotlib.patches.Wedge at 0x11af5e210>,
#   <matplotlib.patches.Wedge at 0x11af48190>,
#   <matplotlib.patches.Wedge at 0x11af48290>,
#   <matplotlib.patches.Wedge at 0x11af78110>,
#   <matplotlib.patches.Wedge at 0x11af78210>],
#  [Text(0.01859164970334871, 1.0998428753968943, 'Jan'),
#   Text(0.3902552388017807, 1.0284458413488604, 'Feb'),
#   Text(1.102129391054306, 0.6894278826492766, 'Mar'),
#   Text(1.0742576608362222, -0.23658080677580023, 'April'),
#   Text(0.6653465155411231, -0.8759646192953721, 'May'),
#   Text(0.035492113515391534, -1.0994272644782876, 'June'),
#   Text(-0.8418451676937796, -0.9906042164409721, 'July'),
#   Text(-1.0505243404722702, -0.32618799805526555, 'Aug'),
#   Text(-1.0974513713331921, -0.07483640530447949, 'Sept'),
#   Text(-1.0351239683996607, 0.37218056107827363, 'Oct'),
#   Text(-0.7255580231333286, 0.8267802338389909, 'Nov'),
#   Text(-0.32099645047811015, 1.0521222736832703, 'Dec')],
#  [Text(0.010140899838190205, 0.5999142956710332, '3.3%'),
#   Text(0.21286649389188037, 0.5609704589175601, '7.7%'),
#   Text(0.6782334714180345, 0.4242633123995547, '13.0%'),
#   Text(0.5859587240924847, -0.12904407642316373, '11.7%'),
#   Text(0.3629162812042489, -0.4777988832520211, '10.7%'),
#   Text(0.019359334644759016, -0.5996875988063386, '8.9%'),
#   Text(-0.5180585647346335, -0.6096025947329059, '14.5%'),
#   Text(-0.5730132766212382, -0.177920726211963, '3.5%'),
#   Text(-0.5986098389090138, -0.04081985743880699, '3.9%'),
#   Text(-0.5646130736725421, 0.20300757876996742, '9.2%'),
#   Text(-0.3957589217090883, 0.45097103663944954, '6.9%'),
#   Text(-0.17508897298806006, 0.573884876554511, '6.6%')])
